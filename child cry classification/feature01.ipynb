# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import librosa
import numpy as np
import pandas as pd
from IPython.display import Audio

# %%
(audio, fs) = librosa.load('/content/drive/My Drive/child cry classification/donateacry_corpus_cleaned_and_updated_data/hungry/0a983cd2-0078-4698-a048-99ac01eb167a-1433917038889-1.7-f-04-hu.wav')

# %%
Audio(audio, rate = fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def lpc(audio, order):
  return librosa.core.lpc(audio, order)

# %%
librosa.lpc(audio, 10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-4fda8f133631> in <module>()
# ----> 1 librosa.lpc(audio, 10)
#
# AttributeError: module 'librosa' has no attribute 'lpc'

# %%
type(audio)
# Out:
# numpy.ndarray

# %%
audio.shape
# Out:
# (150822,)

# %%
# !python --version
# Out:
# Python 3.6.9
